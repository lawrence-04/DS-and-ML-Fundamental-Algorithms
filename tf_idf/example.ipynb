# %%
import jupyter_black

jupyter_black.load()

# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

from tf_idf import vectorise_corpus

# %%
reviews = [
    "This laptop is amazing! Super fast and reliable.",
    "Worst purchase ever. The screen broke in a week.",
    "It's okay, not the best but not terrible either.",
    "Love the battery life and the design. Very sleek!",
    "Support was unhelpful and rude. Not buying again.",
]

# %%
tf_idf_vectors = vectorise_corpus(reviews)
tf_idf_dataframe = pd.DataFrame(tf_idf_vectors).fillna(0)
tf_idf_dataframe.head()
# Out:
#       this   laptop       is  amazing!    super     fast       and  reliable.  \
# 0  0.20118  0.20118  0.20118   0.20118  0.20118  0.20118  0.063853    0.20118
# 1  0.00000  0.00000  0.00000   0.00000  0.00000  0.00000  0.000000    0.00000
# 2  0.00000  0.00000  0.00000   0.00000  0.00000  0.00000  0.000000    0.00000
# 3  0.00000  0.00000  0.00000   0.00000  0.00000  0.00000  0.056758    0.00000
# 4  0.00000  0.00000  0.00000   0.00000  0.00000  0.00000  0.063853    0.00000
#
#       worst  purchase  ...      life   design.      very    sleek!  support  \
# 0  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000  0.00000
# 1  0.178826  0.178826  ...  0.000000  0.000000  0.000000  0.000000  0.00000
# 2  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000  0.00000
# 3  0.000000  0.000000  ...  0.178826  0.178826  0.178826  0.178826  0.00000
# 4  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000  0.20118
#
# ...

# %%
fig, ax = plt.subplots(figsize=(15, 10))
sns.heatmap(tf_idf_dataframe, ax=ax)
# Out:
# <Axes: >
