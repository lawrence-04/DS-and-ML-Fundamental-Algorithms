# %%
import jupyter_black

jupyter_black.load()

# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt

from genetic_algorithm import TSPGeneticAlgorithm

# %%
NUM_NODES = 20
NODE_COORDS = np.random.rand(NUM_NODES, 2)

ga = TSPGeneticAlgorithm(node_coords=NODE_COORDS)

# %%
best_fitness, best_route = ga.optimise()
# Out:
# 100%|██████████| 500/500 [00:08<00:00, 61.09it/s]

# %%
plt.plot(ga.best_fitnesses)
plt.title("Best fitness over time")
plt.xlabel("Iteration")
plt.ylabel("Fitness")
plt.grid(True)

# %%
route_coords = NODE_COORDS[np.concat([best_route, [best_route[0]]])]  # Return to start
plt.plot(route_coords[:, 0], route_coords[:, 1], "o-", color="blue")
plt.title("Best Route Found")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
